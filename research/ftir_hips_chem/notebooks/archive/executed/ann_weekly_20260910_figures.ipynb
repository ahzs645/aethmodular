# %% [markdown]
# # Addis FTIR weekly figures
#
# Graphs for the September 10 weekly presentation, generated from the completed analysis tables. No model refitting or held-out scoring happens here.
#
# Run the source notebook from `research/ftir_hips_chem/` using the repository's uv environment. This executed copy is archived under `notebooks/archive/executed/`. The active source notebook is `research/ftir_hips_chem/ann_weekly_20260910_figures.ipynb`.
#
# The primary selection uses the median spectrum and removes 1800–2500 cm⁻¹. Seasons use `dry_feb`. Addis results are exploratory. The 166/73 split is an unscored retrospective proposal. Deming intervals condition on the chosen model, MAC and λ. TOR tests differ between cohorts. Full methods and audit trails are in the analysis report.

# %%
import sys
sys.path.insert(0, './scripts')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from config import (
    SITES, PROCESSED_SITES_DIR, FILTER_DATA_PATH,
    AERONET_DATA_DIR, WEATHER_DATA_DIR, MAC_VALUE,
)
from outliers import (
    EXCLUDED_SAMPLES, MANUAL_OUTLIERS,
    apply_exclusion_flags, apply_threshold_flags,
    get_clean_data, print_exclusion_summary,
)
from data_matching import (
    load_aethalometer_data, load_filter_data,
    match_aeth_filter_data, match_all_parameters,
)
from etad_factors import load_etad_factor_contributions, match_etad_factors
from aeronet import load_aeronet, aeronet_dir, COLS as AERONET_COLS
from improve_io import load_improve_clean
from plotting import PlotConfig, crossplots, timeseries, distributions, comparisons
from plotting.utils import calculate_regression_stats

PlotConfig.set(sites='all', layout='individual', show_stats=True, show_1to1=True,
               figsize=(14.8, 5.6), font_size=18, title_size=22)

from pathlib import Path
from IPython.display import display
from plotting.ann_weekly_figures import AnnWeeklyFigures

# %%
report = AnnWeeklyFigures(Path.cwd().parents[1])
print(f'Input tables: {report.tables}')
print(f'PNG exports: {report.output}')
print(f'Addis filters: {len(report.addis)}; MAC: {MAC_VALUE}')
# Out:
# Input tables: /Users/ahmadjalil/github/aethmodular/research/ftir_hips_chem/output/tables/ann_weekly_20260910
# PNG exports: /Users/ahmadjalil/github/aethmodular/research/ftir_hips_chem/output/plots/ann_weekly_20260910_notebook
# Addis filters: 239; MAC: 10

# %% [markdown]
# ## Slide 2: Spectral exclusion regions

# %%
fig = report.spectral_regions()
png = report.save(fig, 2)
display(fig)
plt.close(fig)
print(png)
# Out:
# /Users/ahmadjalil/github/aethmodular/research/ftir_hips_chem/output/plots/ann_weekly_20260910_notebook/slide_02.png

# %% [markdown]
# ## Slide 3: Changes in membership and seasonal overlap

# %%
fig = report.membership_changes()
png = report.save(fig, 3)
display(fig)
plt.close(fig)
print(png)
# Out:
# /Users/ahmadjalil/github/aethmodular/research/ftir_hips_chem/output/plots/ann_weekly_20260910_notebook/slide_03.png

# %% [markdown]
# ## Slide 4: Seasonal regressions

# %%
fig = report.seasonal_crossplots()
png = report.save(fig, 4)
display(fig)
plt.close(fig)
print(png)
# Out:
# /Users/ahmadjalil/github/aethmodular/research/ftir_hips_chem/output/plots/ann_weekly_20260910_notebook/slide_04.png

# %% [markdown]
# ## Slide 5: PMF comparison

# %%
fig = report.pmf_comparison()
png = report.save(fig, 5)
display(fig)
plt.close(fig)
print(png)
# Out:
# /Users/ahmadjalil/github/aethmodular/research/ftir_hips_chem/output/plots/ann_weekly_20260910_notebook/slide_05.png

# %% [markdown]
# ## Slide 6: Training membership and Bishoftu provenance

# %%
fig = report.provenance()
png = report.save(fig, 6)
display(fig)
plt.close(fig)
print(png)
# Out:
# /Users/ahmadjalil/github/aethmodular/research/ftir_hips_chem/output/plots/ann_weekly_20260910_notebook/slide_06.png

# %% [markdown]
# ## Slide 7: Proposed Addis selection / validation split

# %%
fig = report.proposed_split()
png = report.save(fig, 7)
display(fig)
plt.close(fig)
print(png)
# Out:
# /Users/ahmadjalil/github/aethmodular/research/ftir_hips_chem/output/plots/ann_weekly_20260910_notebook/slide_07.png

# %% [markdown]
# ## Slide 8: Deming 95% confidence intervals

# %%
fig = report.uncertainty()
png = report.save(fig, 8)
display(fig)
plt.close(fig)
print(png)
# Out:
# /Users/ahmadjalil/github/aethmodular/research/ftir_hips_chem/output/plots/ann_weekly_20260910_notebook/slide_08.png

# %% [markdown]
# ## Slide 9: Calibration screening comparison

# %%
fig = report.benchmark()
png = report.save(fig, 9)
display(fig)
plt.close(fig)
print(png)
# Out:
# /Users/ahmadjalil/github/aethmodular/research/ftir_hips_chem/output/plots/ann_weekly_20260910_notebook/slide_09.png

# %% [markdown]
# ## Slide 10: Dry: every training and Addis spectrum

# %%
fig = report.full_spectra(report.seasons[0])
png = report.save(fig, 10)
display(fig)
plt.close(fig)
print(png)
# Out:
# /Users/ahmadjalil/github/aethmodular/research/ftir_hips_chem/output/plots/ann_weekly_20260910_notebook/slide_10.png

# %% [markdown]
# ## Slide 11: Belg: every training and Addis spectrum

# %%
fig = report.full_spectra(report.seasons[1])
png = report.save(fig, 11)
display(fig)
plt.close(fig)
print(png)
# Out:
# /Users/ahmadjalil/github/aethmodular/research/ftir_hips_chem/output/plots/ann_weekly_20260910_notebook/slide_11.png

# %% [markdown]
# ## Slide 12: Kiremt: every training and Addis spectrum

# %%
fig = report.full_spectra(report.seasons[2])
png = report.save(fig, 12)
display(fig)
plt.close(fig)
print(png)
# Out:
# /Users/ahmadjalil/github/aethmodular/research/ftir_hips_chem/output/plots/ann_weekly_20260910_notebook/slide_12.png
