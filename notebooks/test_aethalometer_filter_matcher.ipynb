# %% [markdown]
# # Test Aethalometer-Filter Matcher Module
#
# Simple test of the new modular aethalometer-filter matching system.

# %%
# Import the module
import sys
sys.path.append('..')

from src.data.loaders import AethalometerFilterMatcher, quick_match
import pandas as pd

print("✅ Module imported successfully!")
# Out:
# ✅ Module imported successfully!

# %%
# Test 1: Using the quick_match function
print("🚀 Testing quick_match function for ETAD...")

aethalometer_path = "../FTIR_HIPS_Chem/df_Jacros_9am_resampled.pkl"
filter_db_path = "../FTIR_HIPS_Chem/Filter Data/unified_filter_dataset.pkl"

try:
    matched_data = quick_match(aethalometer_path, filter_db_path, 'ETAD')
    print(f"\n✅ Quick match successful! Shape: {matched_data.shape}")
    print(f"Columns: {list(matched_data.columns)}")
except Exception as e:
    print(f"❌ Quick match failed: {e}")
# Out:
# 🚀 Testing quick_match function for ETAD...
# Loading complete filter dataset from ../FTIR_HIPS_Chem/Filter Data/unified_filter_dataset.pkl...
# Dataset loaded successfully!
#    Total measurements: 44,493
#    Unique filters: 1,603
#    Sites: CHTS, ETAD, INDH, USPA
#    Date range: 2013-06-28 to 2024-12-08
#    Data sources: ChemSpec, FTIR, HIPS
# ✅ Filter database loaded from: ../FTIR_HIPS_Chem/Filter Data/unified_filter_dataset.pkl
# 🔗 Matching aethalometer and filter data for ETAD...
# ✅ Aethalometer data loaded from: ../FTIR_HIPS_Chem/df_Jacros_9am_resampled.pkl
#    Dataset shape: (1047, 320)
#    Date range: 2022-04-13 09:00:00+03:00 to 2025-06-25 09:00:00+03:00
#    No 'Site' column found - assuming single site data
# 📍 No 'Site' column - assuming all data is for ETAD
# 📂 Extracting ETAD filter measurements...
#    ✅ EC_ftir: 190 measurements
#       Date range: 2022-12-07 to 2024-09-21
#    ✅ HIPS_Fabs: 190 measurements
#       Date range: 2022-12-07 to 2024-09-21
#    ✅ Iron_ChemSpec: 188 measurements
#       Date range: 2022-12-07 to 2024-09-12
#
# ✅ Combined filter dataset: (192, 4)
#    Date range: 2022-12-07 to 2024-09-21
#    Data completeness:
#      EC_ftir: 192/192 (100.0%)
#      HIPS_Fabs: 192/192 (100.0%)
#      Iron_ChemSpec: 191/192 (99.5%)
# 📅 Aethalometer data: 1047 daily averages
#    Date range: 2022-04-13 to 2025-06-25
# 📅 Filter data: 192 samples
#    Date range: 2022-12-07 to 2024-09-21
#
# 🎯 Overlapping dates: 172
#    Date range: 2022-12-07 to 2024-09-21
#
# ✅ Successfully merged 175 matching records!
#
# 📊 Matched dataset summary:
#    Total records: 175
#    Date range: 2022-12-07 to 2024-09-21
#
#    Available measurements:
#      Blue BC1 smoothed: 175 values
#      Blue BC2 smoothed: 175 values
#      Blue BCc smoothed: 175 values
#      Green BC1 smoothed: 175 values
#      Green BC2 smoothed: 175 values
#      Green BCc smoothed: 175 values
#      Serial number: 175 values
#      day_9am: 175 values
#      index: 175 values
#      Unnamed: 0: 175 values
#      Accel X: 175 values
#      Accel Y: 175 values
#      Accel Z: 175 values
#      Blue ATN1: 175 values
#      Blue ATN2: 175 values
#      Blue BC1: 175 values
#      Blue BC2: 175 values
#      Blue BCc: 175 values
#      Blue K: 175 values
#      Blue Ref: 175 values
#      Blue Sen1: 175 values
#      Blue Sen1/Ref: 175 values
#      Blue Sen2: 175 values
#      Blue Sen2/Ref: 175 values
#      Datum ID: 175 values
#      Datum ID API: 130 values
#      Firmware version: 175 values
#      Flow setpoint (mL/min): 175 values
#      Flow total (mL/min): 175 values
#      Flow1 (mL/min): 175 values
#      Flow2 (mL/min): 175 values
#      GPS lat (ddmm.mmmmm): 175 values
#      GPS long (dddmm.mmmmm): 175 values
#      GPS sat count: 175 values
#      Green ATN1: 175 values
#      Green ATN2: 175 values
#      Green BC1: 175 values
#      Green BC2: 175 values
#      Green BCc: 175 values
#      Green K: 175 values
#      Green Ref: 175 values
#      Green Sen1: 175 values
#      Green Sen1/Ref: 175 values
#      Green Sen2: 175 values
#      Green Sen2/Ref: 175 values
#      IR ATN1: 175 values
#      IR ATN2: 175 values
#      IR BC1: 175 values
#      IR BC2: 175 values
#      IR BCc: 175 values
#      IR K: 175 values
#      IR Ref: 175 values
#      IR Sen1: 175 values
#      IR Sen1/Ref: 175 values
#      IR Sen2: 175 values
#      IR Sen2/Ref: 175 values
#      Internal pressure (Pa): 175 values
#      Internal temp (C): 175 values
#      Red ATN1: 175 values
#      Red ATN2: 175 values
#      Red BC1: 175 values
#      Red BC2: 175 values
#      Red BCc: 175 values
#      Red K: 175 values
#      Red Ref: 175 values
#      Red Sen1: 175 values
#      Red Sen1/Ref: 175 values
#      Red Sen2: 175 values
#      Red Sen2/Ref: 175 values
#      Sample RH (%): 175 values
#      Sample RH (%) - scd: 0 values
#      Sample dewpoint (C): 175 values
#      Sample temp (C): 175 values
#      Sample temp (C) - scd: 0 values
#      Session ID: 175 values
#      Status: 175 values
#      Tape position: 175 values
#      Timebase (s): 175 values
#      Timezone offset (mins): 82 values
#      UV ATN1: 175 values
#      UV ATN2: 175 values
#      UV BC1: 175 values
#      UV BC2: 175 values
#      UV BCc: 175 values
#      UV K: 175 values
#      UV Ref: 175 values
#      UV Sen1: 175 values
#      UV Sen1/Ref: 175 values
#      UV Sen2: 175 values
#      UV Sen2/Ref: 175 values
#      WF firmware version: 130 values
#      co2.co2: 104 values
#      co2.relativeHumidity: 104 values
#      co2.temperature: 104 values
#      dataSeriesId: 130 values
#      datasetId: 10 values
#      deltaC1: 175 values
#      deltaC2: 175 values
#      deltaCc: 175 values
#      logId: 104 values
#      ma.env.iinternal.pressure: 0 values
#      ma.env.iinternal.temp: 0 values
#      ma.env.isample.dewpoint: 0 values
#      ma.env.isample.rh: 0 values
#      ma.env.isample.temp: 0 values
#      ma.flow.if1: 0 values
#      ma.flow.if2: 0 values
#      ma.flow.itotal: 0 values
#      ma.wavelengths.iblue.atn.a1: 0 values
#      ma.wavelengths.iblue.atn.a2: 0 values
#      ma.wavelengths.iblue.atn.ak: 0 values
#      ma.wavelengths.iblue.bc.b1: 0 values
#      ma.wavelengths.iblue.bc.b2: 0 values
#      ma.wavelengths.iblue.bc.bc: 0 values
#      ma.wavelengths.iblue.sensor.ref: 0 values
#      ma.wavelengths.iblue.sensor.s1: 0 values
#      ma.wavelengths.iblue.sensor.s2: 0 values
#      ma.wavelengths.igreen.atn.a1: 0 values
#      ma.wavelengths.igreen.atn.a2: 0 values
#      ma.wavelengths.igreen.atn.ak: 0 values
#      ma.wavelengths.igreen.bc.b1: 0 values
#      ma.wavelengths.igreen.bc.b2: 0 values
#      ma.wavelengths.igreen.bc.bc: 0 values
#      ma.wavelengths.igreen.sensor.ref: 0 values
#      ma.wavelengths.igreen.sensor.s1: 0 values
#      ma.wavelengths.igreen.sensor.s2: 0 values
#      ma.wavelengths.iir.atn.a1: 0 values
#      ma.wavelengths.iir.atn.a2: 0 values
#      ma.wavelengths.iir.atn.ak: 0 values
#      ma.wavelengths.iir.bc.b1: 0 values
#      ma.wavelengths.iir.bc.b2: 0 values
#      ma.wavelengths.iir.bc.bc: 0 values
#      ma.wavelengths.iir.sensor.ref: 0 values
#      ma.wavelengths.iir.sensor.s1: 0 values
#      ma.wavelengths.iir.sensor.s2: 0 values
#      ma.wavelengths.ired.atn.a1: 0 values
#      ma.wavelengths.ired.atn.a2: 0 values
#      ma.wavelengths.ired.atn.ak: 0 values
#      ma.wavelengths.ired.bc.b1: 0 values
#      ma.wavelengths.ired.bc.b2: 0 values
#      ma.wavelengths.ired.bc.bc: 0 values
#      ma.wavelengths.ired.sensor.ref: 0 values
#      ma.wavelengths.ired.sensor.s1: 0 values
#      ma.wavelengths.ired.sensor.s2: 0 values
#      ma.wavelengths.iuv.atn.a1: 0 values
#      ma.wavelengths.iuv.atn.a2: 0 values
#      ma.wavelengths.iuv.atn.ak: 0 values
#      ma.wavelengths.iuv.bc.b1: 0 values
#      ma.wavelengths.iuv.bc.b2: 0 values
#      ma.wavelengths.iuv.bc.bc: 0 values
#      ma.wavelengths.iuv.sensor.ref: 0 values
#      ma.wavelengths.iuv.sensor.s1: 0 values
#      ma.wavelengths.iuv.sensor.s2: 0 values
#      metadataId: 104 values
#      missingDatumId: 0 values
#      opc.bins.i0: 26 values
#      opc.bins.i1: 26 values
#      opc.bins.i10: 26 values
#      opc.bins.i11: 26 values
#      opc.bins.i12: 26 values
#      opc.bins.i13: 26 values
#      opc.bins.i14: 26 values
#      opc.bins.i15: 26 values
#      opc.bins.i16: 26 values
#      opc.bins.i17: 26 values
#      opc.bins.i18: 26 values
#      opc.bins.i19: 26 values
#      opc.bins.i2: 26 values
#      opc.bins.i20: 26 values
#      opc.bins.i21: 26 values
#      opc.bins.i22: 26 values
#      opc.bins.i23: 26 values
#      opc.bins.i3: 26 values
#      opc.bins.i4: 26 values
#      opc.bins.i5: 26 values
#      opc.bins.i6: 26 values
#      opc.bins.i7: 26 values
#      opc.bins.i8: 26 values
#      opc.bins.i9: 26 values
#      opc.pms.i0: 26 values
#      opc.pms.i1: 26 values
#      opc.pms.i2: 26 values
#      particulate.counts.i0: 104 values
#      particulate.counts.i1: 104 values
#      particulate.counts.i10: 104 values
#      particulate.counts.i11: 104 values
#      particulate.counts.i12: 104 values
#      particulate.counts.i13: 104 values
#      particulate.counts.i14: 104 values
#      particulate.counts.i15: 104 values
#      particulate.counts.i16: 104 values
#      particulate.counts.i17: 104 values
#      particulate.counts.i18: 104 values
#      particulate.counts.i19: 104 values
#      particulate.counts.i2: 104 values
#      particulate.counts.i20: 104 values
#      particulate.counts.i21: 104 values
#      particulate.counts.i22: 104 values
#      particulate.counts.i23: 104 values
#      particulate.counts.i3: 104 values
#      particulate.counts.i4: 104 values
#      particulate.counts.i5: 104 values
#      particulate.counts.i6: 104 values
#      particulate.counts.i7: 104 values
#      particulate.counts.i8: 104 values
#      particulate.counts.i9: 104 values
#      particulate.masses.i0: 104 values
#      particulate.masses.i1: 104 values
#      particulate.masses.i2: 104 values
#      particulate.particleSize: 104 values
#      publishedInRealtime: 19 values
#      published_in_realtime: 86 values
#      ratio_flow: 175 values
#      scd.co2: 0 values
#      statusId: 104 values
#      timezoneOffset: 130 values
#      transfer: 130 values
#      unixtime: 130 values
#      updated: 32 values
#      App version: 59 values
#      Battery remaining (%): 59 values
#      Data format version: 59 values
#      GPS speed (km/h): 59 values
#      IR denominator 2: 175 values
#      Red BC1 smoothed: 175 values
#      Red BC2 smoothed: 175 values
#      Red BCc smoothed: 175 values
#      UV BC1 smoothed: 175 values
#      UV BC2 smoothed: 175 values
#      UV BCc smoothed: 175 values
#      IR BC1 smoothed: 175 values
#      IR BC2 smoothed: 175 values
#      IR BCc smoothed: 175 values
#      Blue denominator 2: 175 values
#      Red denominator 2: 175 values
#      Green denominator 2: 175 values
#      UV denominator 2: 175 values
#      delta Blue ATN1: 175 values
#      delta Blue ATN1 rolling mean: 175 values
#      Blue ATN1 rolling mean: 175 values
#      delta Blue ATN2: 175 values
#      delta Blue ATN2 rolling mean: 175 values
#      Blue ATN2 rolling mean: 175 values
#      delta Green ATN1: 175 values
#      delta Green ATN1 rolling mean: 175 values
#      Green ATN1 rolling mean: 175 values
#      delta Green ATN2: 175 values
#      delta Green ATN2 rolling mean: 175 values
#      Green ATN2 rolling mean: 175 values
#      delta IR ATN1: 175 values
#      delta IR ATN1 rolling mean: 175 values
#      IR ATN1 rolling mean: 175 values
#      delta IR ATN2: 175 values
#      delta IR ATN2 rolling mean: 175 values
#      IR ATN2 rolling mean: 175 values
#      delta Red ATN1: 175 values
#      delta Red ATN1 rolling mean: 175 values
#      Red ATN1 rolling mean: 175 values
#      delta Red ATN2: 175 values
#      delta Red ATN2 rolling mean: 175 values
#      Red ATN2 rolling mean: 175 values
#      delta UV ATN1: 175 values
#      delta UV ATN1 rolling mean: 175 values
#      UV ATN1 rolling mean: 175 values
#      delta UV ATN2: 175 values
#      delta UV ATN2 rolling mean: 175 values
#      UV ATN2 rolling mean: 175 values
#      delta Internal temp (C): 175 values
#      delta Internal temp (C) rolling mean: 175 values
#      Internal temp (C) rolling mean: 175 values
#      delta Sample temp (C): 175 values
#      delta Sample temp (C) rolling mean: 175 values
#      Sample temp (C) rolling mean: 175 values
#      delta Sample RH (%): 175 values
#      delta Sample RH (%) rolling mean: 175 values
#      Sample RH (%) rolling mean: 175 values
#      IR_ratio_dATN_flow: 174 values
#      Blue_ratio_dATN_flow: 173 values
#      Red_ratio_dATN_flow: 174 values
#      IR BCc/BC1 smoothed: 175 values
#      IR BCc/BC2 smoothed: 175 values
#      IR BC1/BC2 smoothed: 175 values
#      Blue BCc/BC1 smoothed: 175 values
#      Blue BCc/BC2 smoothed: 175 values
#      Blue BC1/BC2 smoothed: 175 values
#      Red BCc/BC1 smoothed: 175 values
#      Red BCc/BC2 smoothed: 175 values
#      Red BC1/BC2 smoothed: 175 values
#      delta_temp_std: 175 values
#      IR ATN1_roughness: 175 values
#      IR ATN2_roughness: 175 values
#      Blue ATN1_roughness: 175 values
#      Blue ATN2_roughness: 175 values
#      Red ATN1_roughness: 175 values
#      Red ATN2_roughness: 175 values
#      hour: 175 values
#      Optical config: 175 values
#      Readable status: 175 values
#      Readable status - fw format: 175 values
#      dataPlatform: 175 values
#      dateTime: 175 values
#      datetime: 175 values
#      datetime_rounded_1min: 175 values
#      datetime_utc: 175 values
#      deviceFamily: 175 values
#      deviceId:dataSeriesId: 175 values
#      deviceId:datasetId: 175 values
#      deviceId:sessionId: 175 values
#      device_type: 175 values
#      high_rough_period: 175 values
#      id: 175 values
#      lastMetadata: 175 values
#      lastStatus: 175 values
#      source: 175 values
#      sourceMethod: 175 values
#      spot_mode: 175 values
#      test: 175 values
#      transferProtocol: 175 values
#      viaBacklog: 175 values
#      EC_ftir: 175 values
#      HIPS_Fabs: 175 values
#      Iron_ChemSpec: 174 values
#
# ✅ Quick match successful! Shape: (175, 324)
# Columns: ['match_date', 'datetime_local', 'Blue BC1 smoothed', 'Blue BC2 smoothed', 'Blue BCc smoothed', 'Green BC1 smoothed', 'Green BC2 smoothed', 'Green BCc smoothed', 'Serial number', 'day_9am', 'index', 'Unnamed: 0', 'Accel X', 'Accel Y', 'Accel Z', 'Blue ATN1', 'Blue ATN2', 'Blue BC1', 'Blue BC2', 'Blue BCc', 'Blue K', 'Blue Ref', 'Blue Sen1', 'Blue Sen1/Ref', 'Blue Sen2', 'Blue Sen2/Ref', 'Datum ID', 'Datum ID API', 'Firmware version', 'Flow setpoint (mL/min)', 'Flow total (mL/min)', 'Flow1 (mL/min)', 'Flow2 (mL/min)', 'GPS lat (ddmm.mmmmm)', 'GPS long (dddmm.mmmmm)', 'GPS sat count', 'Green ATN1', 'Green ATN2', 'Green BC1', 'Green BC2', 'Green BCc', 'Green K', 'Green Ref', 'Green Sen1', 'Green Sen1/Ref', 'Green Sen2', 'Green Sen2/Ref', 'IR ATN1', 'IR ATN2', 'IR BC1', 'IR BC2', 'IR BCc', 'IR K', 'IR Ref', 'IR Sen1', 'IR Sen1/Ref', 'IR Sen2', 'IR Sen2/Ref', 'Internal pressure (Pa)', 'Internal temp (C)', 'Red ATN1', 'Red ATN2', 'Red BC1', 'Red BC2', 'Red BCc', 'Red K', 'Red Ref', 'Red Sen1', 'Red Sen1/Ref', 'Red Sen2', 'Red Sen2/Ref', 'Sample RH (%)', 'Sample RH (%) - scd', 'Sample dewpoint (C)', 'Sample temp (C)', 'Sample temp (C) - scd', 'Session ID', 'Status', 'Tape position', 'Timebase (s)', 'Timezone offset (mins)', 'UV ATN1', 'UV ATN2', 'UV BC1', 'UV BC2', 'UV BCc', 'UV K', 'UV Ref', 'UV Sen1', 'UV Sen1/Ref', 'UV Sen2', 'UV Sen2/Ref', 'WF firmware version', 'co2.co2', 'co2.relativeHumidity', 'co2.temperature', 'dataSeriesId', 'datasetId', 'deltaC1', 'deltaC2', 'deltaCc', 'logId', 'ma.env.iinternal.pressure', 'ma.env.iinternal.temp', 'ma.env.isample.dewpoint', 'ma.env.isample.rh', 'ma.env.isample.temp', 'ma.flow.if1', 'ma.flow.if2', 'ma.flow.itotal', 'ma.wavelengths.iblue.atn.a1', 'ma.wavelengths.iblue.atn.a2', 'ma.wavelengths.iblue.atn.ak', 'ma.wavelengths.iblue.bc.b1', 'ma.wavelengths.iblue.bc.b2', 'ma.wavelengths.iblue.bc.bc', 'ma.wavelengths.iblue.sensor.ref', 'ma.wavelengths.iblue.sensor.s1', 'ma.wavelengths.iblue.sensor.s2', 'ma.wavelengths.igreen.atn.a1', 'ma.wavelengths.igreen.atn.a2', 'ma.wavelengths.igreen.atn.ak', 'ma.wavelengths.igreen.bc.b1', 'ma.wavelengths.igreen.bc.b2', 'ma.wavelengths.igreen.bc.bc', 'ma.wavelengths.igreen.sensor.ref', 'ma.wavelengths.igreen.sensor.s1', 'ma.wavelengths.igreen.sensor.s2', 'ma.wavelengths.iir.atn.a1', 'ma.wavelengths.iir.atn.a2', 'ma.wavelengths.iir.atn.ak', 'ma.wavelengths.iir.bc.b1', 'ma.wavelengths.iir.bc.b2', 'ma.wavelengths.iir.bc.bc', 'ma.wavelengths.iir.sensor.ref', 'ma.wavelengths.iir.sensor.s1', 'ma.wavelengths.iir.sensor.s2', 'ma.wavelengths.ired.atn.a1', 'ma.wavelengths.ired.atn.a2', 'ma.wavelengths.ired.atn.ak', 'ma.wavelengths.ired.bc.b1', 'ma.wavelengths.ired.bc.b2', 'ma.wavelengths.ired.bc.bc', 'ma.wavelengths.ired.sensor.ref', 'ma.wavelengths.ired.sensor.s1', 'ma.wavelengths.ired.sensor.s2', 'ma.wavelengths.iuv.atn.a1', 'ma.wavelengths.iuv.atn.a2', 'ma.wavelengths.iuv.atn.ak', 'ma.wavelengths.iuv.bc.b1', 'ma.wavelengths.iuv.bc.b2', 'ma.wavelengths.iuv.bc.bc', 'ma.wavelengths.iuv.sensor.ref', 'ma.wavelengths.iuv.sensor.s1', 'ma.wavelengths.iuv.sensor.s2', 'metadataId', 'missingDatumId', 'opc.bins.i0', 'opc.bins.i1', 'opc.bins.i10', 'opc.bins.i11', 'opc.bins.i12', 'opc.bins.i13', 'opc.bins.i14', 'opc.bins.i15', 'opc.bins.i16', 'opc.bins.i17', 'opc.bins.i18', 'opc.bins.i19', 'opc.bins.i2', 'opc.bins.i20', 'opc.bins.i21', 'opc.bins.i22', 'opc.bins.i23', 'opc.bins.i3', 'opc.bins.i4', 'opc.bins.i5', 'opc.bins.i6', 'opc.bins.i7', 'opc.bins.i8', 'opc.bins.i9', 'opc.pms.i0', 'opc.pms.i1', 'opc.pms.i2', 'particulate.counts.i0', 'particulate.counts.i1', 'particulate.counts.i10', 'particulate.counts.i11', 'particulate.counts.i12', 'particulate.counts.i13', 'particulate.counts.i14', 'particulate.counts.i15', 'particulate.counts.i16', 'particulate.counts.i17', 'particulate.counts.i18', 'particulate.counts.i19', 'particulate.counts.i2', 'particulate.counts.i20', 'particulate.counts.i21', 'particulate.counts.i22', 'particulate.counts.i23', 'particulate.counts.i3', 'part ...

# %%
# Test 2: Using the full matcher class
print("🔧 Testing AethalometerFilterMatcher class...")

try:
    matcher = AethalometerFilterMatcher(aethalometer_path, filter_db_path)
    
    # Check available sites
    sites = matcher.get_available_sites()
    print(f"Available sites: {sites}")
    
    # Match ETAD data with custom parameters
    etad_matched = matcher.match_site_data(
        'ETAD',
        filter_parameters=['EC_ftir', 'HIPS_Fabs', 'ChemSpec_Iron_PM2.5'],
        aethalometer_columns=['IR BCc smoothed', 'Blue BCc smoothed', 'UV BCc smoothed']
    )
    
    print(f"\n✅ Custom match successful! Shape: {etad_matched.shape}")
    
except Exception as e:
    print(f"❌ Matcher class failed: {e}")
# Out:
# 🔧 Testing AethalometerFilterMatcher class...
# Loading complete filter dataset from ../FTIR_HIPS_Chem/Filter Data/unified_filter_dataset.pkl...
# Dataset loaded successfully!
#    Total measurements: 44,493
#    Unique filters: 1,603
#    Sites: CHTS, ETAD, INDH, USPA
#    Date range: 2013-06-28 to 2024-12-08
#    Data sources: ChemSpec, FTIR, HIPS
# ✅ Filter database loaded from: ../FTIR_HIPS_Chem/Filter Data/unified_filter_dataset.pkl
# Available sites: ['CHTS', 'ETAD', 'INDH', 'USPA']
# 🔗 Matching aethalometer and filter data for ETAD...
# ✅ Aethalometer data loaded from: ../FTIR_HIPS_Chem/df_Jacros_9am_resampled.pkl
#    Dataset shape: (1047, 320)
#    Date range: 2022-04-13 09:00:00+03:00 to 2025-06-25 09:00:00+03:00
#    No 'Site' column found - assuming single site data
# 📍 No 'Site' column - assuming all data is for ETAD
# 📂 Extracting ETAD filter measurements...
#    ✅ EC_ftir: 190 measurements
#       Date range: 2022-12-07 to 2024-09-21
#    ✅ HIPS_Fabs: 190 measurements
#       Date range: 2022-12-07 to 2024-09-21
#    ✅ Iron_ChemSpec: 188 measurements
#       Date range: 2022-12-07 to 2024-09-12
#
# ✅ Combined filter dataset: (192, 4)
#    Date range: 2022-12-07 to 2024-09-21
#    Data completeness:
#      EC_ftir: 192/192 (100.0%)
#      HIPS_Fabs: 192/192 (100.0%)
#      Iron_ChemSpec: 191/192 (99.5%)
# 📅 Aethalometer data: 1047 daily averages
#    Date range: 2022-04-13 to 2025-06-25
# 📅 Filter data: 192 samples
#    Date range: 2022-12-07 to 2024-09-21
#
# 🎯 Overlapping dates: 172
#    Date range: 2022-12-07 to 2024-09-21
#
# ✅ Successfully merged 175 matching records!
#
# 📊 Matched dataset summary:
#    Total records: 175
#    Date range: 2022-12-07 to 2024-09-21
#
#    Available measurements:
#      IR BCc smoothed: 175 values
#      Blue BCc smoothed: 175 values
#      UV BCc smoothed: 175 values
#      Serial number: 175 values
#      day_9am: 175 values
#      index: 175 values
#      Unnamed: 0: 175 values
#      Accel X: 175 values
#      Accel Y: 175 values
#      Accel Z: 175 values
#      Blue ATN1: 175 values
#      Blue ATN2: 175 values
#      Blue BC1: 175 values
#      Blue BC2: 175 values
#      Blue BCc: 175 values
#      Blue K: 175 values
#      Blue Ref: 175 values
#      Blue Sen1: 175 values
#      Blue Sen1/Ref: 175 values
#      Blue Sen2: 175 values
#      Blue Sen2/Ref: 175 values
#      Datum ID: 175 values
#      Datum ID API: 130 values
#      Firmware version: 175 values
#      Flow setpoint (mL/min): 175 values
#      Flow total (mL/min): 175 values
#      Flow1 (mL/min): 175 values
#      Flow2 (mL/min): 175 values
#      GPS lat (ddmm.mmmmm): 175 values
#      GPS long (dddmm.mmmmm): 175 values
#      GPS sat count: 175 values
#      Green ATN1: 175 values
#      Green ATN2: 175 values
#      Green BC1: 175 values
#      Green BC2: 175 values
#      Green BCc: 175 values
#      Green K: 175 values
#      Green Ref: 175 values
#      Green Sen1: 175 values
#      Green Sen1/Ref: 175 values
#      Green Sen2: 175 values
#      Green Sen2/Ref: 175 values
#      IR ATN1: 175 values
#      IR ATN2: 175 values
#      IR BC1: 175 values
#      IR BC2: 175 values
#      IR BCc: 175 values
#      IR K: 175 values
#      IR Ref: 175 values
#      IR Sen1: 175 values
#      IR Sen1/Ref: 175 values
#      IR Sen2: 175 values
#      IR Sen2/Ref: 175 values
#      Internal pressure (Pa): 175 values
#      Internal temp (C): 175 values
#      Red ATN1: 175 values
#      Red ATN2: 175 values
#      Red BC1: 175 values
#      Red BC2: 175 values
#      Red BCc: 175 values
#      Red K: 175 values
#      Red Ref: 175 values
#      Red Sen1: 175 values
#      Red Sen1/Ref: 175 values
#      Red Sen2: 175 values
#      Red Sen2/Ref: 175 values
#      Sample RH (%): 175 values
#      Sample RH (%) - scd: 0 values
#      Sample dewpoint (C): 175 values
#      Sample temp (C): 175 values
#      Sample temp (C) - scd: 0 values
#      Session ID: 175 values
#      Status: 175 values
#      Tape position: 175 values
#      Timebase (s): 175 values
#      Timezone offset (mins): 82 values
#      UV ATN1: 175 values
#      UV ATN2: 175 values
#      UV BC1: 175 values
#      UV BC2: 175 values
#      UV BCc: 175 values
#      UV K: 175 values
#      UV Ref: 175 values
#      UV Sen1: 175 values
#      UV Sen1/Ref: 175 values
#      UV Sen2: 175 values
#      UV Sen2/Ref: 175 values
#      WF firmware version: 130 values
#      co2.co2: 104 values
#      co2.relativeHumidity: 104 values
#      co2.temperature: 104 values
#      dataSeriesId: 130 values
#      datasetId: 10 values
#      deltaC1: 175 values
#      deltaC2: 175 values
#      deltaCc: 175 values
#      logId: 104 values
#      ma.env.iinternal.pressure: 0 values
#      ma.env.iinternal.temp: 0 values
#      ma.env.isample.dewpoint: 0 values
#      ma.env.isample.rh: 0 values
#      ma.env.isample.temp: 0 values
#      ma.flow.if1: 0 values
#      ma.flow.if2: 0 values
#      ma.flow.itotal: 0 values
#      ma.wavelengths.iblue.atn.a1: 0 values
#      ma.wavelengths.iblue.atn.a2: 0 values
#      ma.wavelengths.iblue.atn.ak: 0 values
#      ma.wavelengths.iblue.bc.b1: 0 values
#      ma.wavelengths.iblue.bc.b2: 0 values
#      ma.wavelengths.iblue.bc.bc: 0 values
#      ma.wavelengths.iblue.sensor.ref: 0 values
#      ma.wavelengths.iblue.sensor.s1: 0 values
#      ma.wavelengths.iblue.sensor.s2: 0 values
#      ma.wavelengths.igreen.atn.a1: 0 values
#      ma.wavelengths.igreen.atn.a2: 0 values
#      ma.wavelengths.igreen.atn.ak: 0 values
#      ma.wavelengths.igreen.bc.b1: 0 values
#      ma.wavelengths.igreen.bc.b2: 0 values
#      ma.wavelengths.igreen.bc.bc: 0 values
#      ma.wavelengths.igreen.sensor.ref: 0 values
#      ma.wavelengths.igreen.sensor.s1: 0 values
#      ma.wavelengths.igreen.sensor.s2: 0 values
#      ma.wavelengths.iir.atn.a1: 0 values
#      ma.wavelengths.iir.atn.a2: 0 values
#      ma.wavelengths.iir.atn.ak: 0 values
#      ma.wavelengths.iir.bc.b1: 0 values
#      ma.wavelengths.iir.bc.b2: 0 values
#      ma.wavelengths.iir.bc.bc: 0 values
#      ma.wavelengths.iir.sensor.ref: 0 values
#      ma.wavelengths.iir.sensor.s1: 0 values
#      ma.wavelengths.iir.sensor.s2: 0 values
#      ma.wavelengths.ired.atn.a1: 0 values
#      ma.wavelengths.ired.atn.a2: 0 values
#      ma.wavelengths.ired.atn.ak: 0 values
#      ma.wavelengths.ired.bc.b1: 0 values
#      ma.wavelengths.ired.bc.b2: 0 values
#      ma.wavelengths.ired.bc.bc: 0 values
#      ma.wavelengths.ired.sensor.ref: 0 values
#      ma.wavelengths.ired.sensor.s1: 0 values
#      ma.wavelengths.ired.sensor.s2: 0 values
#      ma.wavelengths.iuv.atn.a1: 0 values
#      ma.wavelengths.iuv.atn.a2: 0 values
#      ma.wavelengths.iuv.atn.ak: 0 values
#      ma.wavelengths.iuv.bc.b1: 0 values
#      ma.wavelengths.iuv.bc.b2: 0 values
#      ma.wavelengths.iuv.bc.bc: 0 values
#      ma.wavelengths.iuv.sensor.ref: 0 values
#      ma.wavelengths.iuv.sensor.s1: 0 values
#      ma.wavelengths.iuv.sensor.s2: 0 values
#      metadataId: 104 values
#      missingDatumId: 0 values
#      opc.bins.i0: 26 values
#      opc.bins.i1: 26 values
#      opc.bins.i10: 26 values
#      opc.bins.i11: 26 values
#      opc.bins.i12: 26 values
#      opc.bins.i13: 26 values
#      opc.bins.i14: 26 values
#      opc.bins.i15: 26 values
#      opc.bins.i16: 26 values
#      opc.bins.i17: 26 values
#      opc.bins.i18: 26 values
#      opc.bins.i19: 26 values
#      opc.bins.i2: 26 values
#      opc.bins.i20: 26 values
#      opc.bins.i21: 26 values
#      opc.bins.i22: 26 values
#      opc.bins.i23: 26 values
#      opc.bins.i3: 26 values
#      opc.bins.i4: 26 values
#      opc.bins.i5: 26 values
#      opc.bins.i6: 26 values
#      opc.bins.i7: 26 values
#      opc.bins.i8: 26 values
#      opc.bins.i9: 26 values
#      opc.pms.i0: 26 values
#      opc.pms.i1: 26 values
#      opc.pms.i2: 26 values
#      particulate.counts.i0: 104 values
#      particulate.counts.i1: 104 values
#      particulate.counts.i10: 104 values
#      particulate.counts.i11: 104 values
#      particulate.counts.i12: 104 values
#      particulate.counts.i13: 104 values
#      particulate.counts.i14: 104 values
#      particulate.counts.i15: 104 values
#      particulate.counts.i16: 104 values
#      particulate.counts.i17: 104 values
#      particulate.counts.i18: 104 values
#      particulate.counts.i19: 104 values
#      particulate.counts.i2: 104 values
#      particulate.counts.i20: 104 values
#      particulate.counts.i21: 104 values
#      particulate.counts.i22: 104 values
#      particulate.counts.i23: 104 values
#      particulate.counts.i3: 104 values
#      particulate.counts.i4: 104 values
#      particulate.counts.i5: 104 values
#      particulate.counts.i6: 104 values
#      particulate.counts.i7: 104 values
#      particulate.counts.i8: 104 values
#      particulate.counts.i9: 104 values
#      particulate.masses.i0: 104 values
#      particulate.masses.i1: 104 values
#      particulate.masses.i2: 104 values
#      particulate.particleSize: 104 values
#      publishedInRealtime: 19 values
#      published_in_realtime: 86 values
#      ratio_flow: 175 values
#      scd.co2: 0 values
#      statusId: 104 values
#      timezoneOffset: 130 values
#      transfer: 130 values
#      unixtime: 130 values
#      updated: 32 values
#      App version: 59 values
#      Battery remaining (%): 59 values
#      Data format version: 59 values
#      GPS speed (km/h): 59 values
#      IR denominator 2: 175 values
#      Blue BC1 smoothed: 175 values
#      Blue BC2 smoothed: 175 values
#      Green BC1 smoothed: 175 values
#      Green BC2 smoothed: 175 values
#      Green BCc smoothed: 175 values
#      Red BC1 smoothed: 175 values
#      Red BC2 smoothed: 175 values
#      Red BCc smoothed: 175 values
#      UV BC1 smoothed: 175 values
#      UV BC2 smoothed: 175 values
#      IR BC1 smoothed: 175 values
#      IR BC2 smoothed: 175 values
#      Blue denominator 2: 175 values
#      Red denominator 2: 175 values
#      Green denominator 2: 175 values
#      UV denominator 2: 175 values
#      delta Blue ATN1: 175 values
#      delta Blue ATN1 rolling mean: 175 values
#      Blue ATN1 rolling mean: 175 values
#      delta Blue ATN2: 175 values
#      delta Blue ATN2 rolling mean: 175 values
#      Blue ATN2 rolling mean: 175 values
#      delta Green ATN1: 175 values
#      delta Green ATN1 rolling mean: 175 values
#      Green ATN1 rolling mean: 175 values
#      delta Green ATN2: 175 values
#      delta Green ATN2 rolling mean: 175 values
#      Green ATN2 rolling mean: 175 values
#      delta IR ATN1: 175 values
#      delta IR ATN1 rolling mean: 175 values
#      IR ATN1 rolling mean: 175 values
#      delta IR ATN2: 175 values
#      delta IR ATN2 rolling mean: 175 values
#      IR ATN2 rolling mean: 175 values
#      delta Red ATN1: 175 values
#      delta Red ATN1 rolling mean: 175 values
#      Red ATN1 rolling mean: 175 values
#      delta Red ATN2: 175 values
#      delta Red ATN2 rolling mean: 175 values
#      Red ATN2 rolling mean: 175 values
#      delta UV ATN1: 175 values
#      delta UV ATN1 rolling mean: 175 values
#      UV ATN1 rolling mean: 175 values
#      delta UV ATN2: 175 values
#      delta UV ATN2 rolling mean: 175 values
#      UV ATN2 rolling mean: 175 values
#      delta Internal temp (C): 175 values
#      delta Internal temp (C) rolling mean: 175 values
#      Internal temp (C) rolling mean: 175 values
#      delta Sample temp (C): 175 values
#      delta Sample temp (C) rolling mean: 175 values
#      Sample temp (C) rolling mean: 175 values
#      delta Sample RH (%): 175 values
#      delta Sample RH (%) rolling mean: 175 values
#      Sample RH (%) rolling mean: 175 values
#      IR_ratio_dATN_flow: 174 values
#      Blue_ratio_dATN_flow: 173 values
#      Red_ratio_dATN_flow: 174 values
#      IR BCc/BC1 smoothed: 175 values
#      IR BCc/BC2 smoothed: 175 values
#      IR BC1/BC2 smoothed: 175 values
#      Blue BCc/BC1 smoothed: 175 values
#      Blue BCc/BC2 smoothed: 175 values
#      Blue BC1/BC2 smoothed: 175 values
#      Red BCc/BC1 smoothed: 175 values
#      Red BCc/BC2 smoothed: 175 values
#      Red BC1/BC2 smoothed: 175 values
#      delta_temp_std: 175 values
#      IR ATN1_roughness: 175 values
#      IR ATN2_roughness: 175 values
#      Blue ATN1_roughness: 175 values
#      Blue ATN2_roughness: 175 values
#      Red ATN1_roughness: 175 values
#      Red ATN2_roughness: 175 values
#      hour: 175 values
#      Optical config: 175 values
#      Readable status: 175 values
#      Readable status - fw format: 175 values
#      dataPlatform: 175 values
#      dateTime: 175 values
#      datetime: 175 values
#      datetime_rounded_1min: 175 values
#      datetime_utc: 175 values
#      deviceFamily: 175 values
#      deviceId:dataSeriesId: 175 values
#      deviceId:datasetId: 175 values
#      deviceId:sessionId: 175 values
#      device_type: 175 values
#      high_rough_period: 175 values
#      id: 175 values
#      lastMetadata: 175 values
#      lastStatus: 175 values
#      source: 175 values
#      sourceMethod: 175 values
#      spot_mode: 175 values
#      test: 175 values
#      transferProtocol: 175 values
#      viaBacklog: 175 values
#      EC_ftir: 175 values
#      HIPS_Fabs: 175 values
#      Iron_ChemSpec: 174 values
#
# ✅ Custom match successful! Shape: (175, 324)

# %%
# Test 3: Get correlation summary
if 'matched_data' in locals() and not matched_data.empty:
    print("📊 Testing correlation summary...")
    
    try:
        corr_summary = matcher.get_correlation_summary(matched_data)
        
        print(f"\n🔗 Correlation Summary:")
        for label, stats in corr_summary['correlations'].items():
            print(f"   {label}: R = {stats['r']:.3f}, R² = {stats['r2']:.3f} (n = {stats['n']})")
            
    except Exception as e:
        print(f"❌ Correlation summary failed: {e}")
else:
    print("⚠️  No matched data available for correlation analysis")
# Out:
# 📊 Testing correlation summary...
#
# 🔗 Correlation Summary:
#    IR BC vs EC: R = 0.929, R² = 0.863 (n = 175)
#    Blue BC vs Fabs: R = 0.866, R² = 0.750 (n = 175)
#    UV BC vs Iron: R = 0.148, R² = 0.022 (n = 174)
#    EC vs Fabs: R = 0.860, R² = 0.740 (n = 175)

# %%
# Show final summary
print("\n🎉 Module testing complete!")
print("The AethalometerFilterMatcher module provides:")
print("   • Easy loading of aethalometer and filter data")
print("   • Automatic date matching between datasets")
print("   • Support for all sites in the database")
print("   • Flexible parameter selection")
print("   • Built-in correlation analysis")
print("\n📖 Usage examples:")
print("   # Simple usage:")
print("   matched = quick_match(aeth_path, filter_path, 'ETAD')")
print("\n   # Advanced usage:")
print("   matcher = AethalometerFilterMatcher(aeth_path, filter_path)")
print("   data = matcher.match_site_data('ETAD', filter_parameters=['EC_ftir'])")
# Out:
# 🎉 Module testing complete!
# The AethalometerFilterMatcher module provides:
#    • Easy loading of aethalometer and filter data
#    • Automatic date matching between datasets
#    • Support for all sites in the database
#    • Flexible parameter selection
#    • Built-in correlation analysis
#
# 📖 Usage examples:
#    # Simple usage:
#    matched = quick_match(aeth_path, filter_path, 'ETAD')
#
#    # Advanced usage:
#    matcher = AethalometerFilterMatcher(aeth_path, filter_path)
#    data = matcher.match_site_data('ETAD', filter_parameters=['EC_ftir'])
